# %% [markdown]
# # Class 23
#
# ---
#
# More Js

# %% [markdown]
# ## Notes for today
#
# **Callback Functions**
#
# ```js
#
# arr = [123,4124,5,12312]
# arr2 = arr.filter(val, index, arr)=>{
#     return value % 2 == 0
# }
#
# ```
#
# ---
#
# **JS Hashmaps**
#
# ```js
#
# var emp = {firstname:'Justin', lastname:'Doe', sal:3400}
# for (let e in emp){
#     emp[e]
# }
#
# // this. will access informationw ithin the object
# var emp2 = {
#     firstname:'justin',
#     lastname:'doe',
#     fullaname: function(){
#         return this.firstname + this.lastname
#     }
# }
#
# emp2.fullname()
#
# ```
#
# ---
#
# **JS string functions**
#
# ```js
#
# var s = "hello world"
# document.write(s[2])
#
# // uppercase
# s.toUpperCase()
# s.toLowerCase()
#
# // join two strings
# var s4 = s.concat(s, "New String")
#
# // length
# s.length
#
# // substring (part of string to a range)
# s.substr(2, 6)
#
# // index?
# s.indexOf('w')
# ```
#
# ---
#
# **Js window**
#
# ```js
#
# let name = prompt(
#     'enter your name'
# )
# alert(name)
#
# let ques = confirm('Are You sure?')
# if (ques){
#     ...
# }else{
#     ...
# }
#
# setTimeout(
#
# )
#
# ```
#
# **Javascript Event**
#
# Change in state of an object. Use predef even tto exe something
# - onclick
# - mouseoverevent
# - onfocus
# - onkeyup
#
#
# DOM (Document object model) --> constructed as tree of objects
# - DOM methods
#     - actions you could perform
#     - values that you could set or change
#
# `document.getElementById` --> finds element in element id
# `document.getElementsByTagName` --> finds element by tag
# `document.getElementsByClassName` --> from class name
#
# ```html
# <html>
#     <body>
#         <button onclick='display()'>Click</button>
#         <p onmouseover='display2()'>Hover over me</p>
#         <input type='text' onchange='display3()' id='inp'>
#         <input type='text' onfocus='changeBg()' id='inp2'>
#         <input type='text' onkeyup='func()' id='inp3'>
#         <p>
#             My name is: <span id='demo'></span>
#         </p>
#
#         <form onsubmit='' name='fm'>
#             <input type='text' name='name'>
#             <button type='button' onclick='getdata()'>
#         </form>
#
#         <script>
#             function display(){
#                 alert('welcome')
#             }
#             function display2(){
#                 alert('welcome 2')
#             }
#             function display3(){
#                 alert(document.getElementById('inp').value)
#                 document.getElementsByTagName('p').length
#             }
#             function changeBg(){
#                 document.getElementById('inp2').style.background = "orange";
#             }
#             function func(){
#                 let data = document.getElementById('inp3')
#                 document.getElemenById('demo').innerHTML=data
#             }
#             function getdata(){
#                 let data=document.fm.name.value
#                 alert(data)
#             }
#
#         </script>
#     </body>
# </html>
#
#
# ```
#
# ---
#
# **Validate** form:
# Name + Password not null
# Password not less than 5 characters
# if null then user cannot submit form
